# %% [markdown]
# <a href="https://colab.research.google.com/github/bbhunterpk-ux/AllAboutBugBounty/blob/master/Copy_of_WebSecProbe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install WebSecProbe

# %%
# !WebSecProbe https://ziva.host premium
# Out:
#
#      _ _ _     _   _____         _____         _
#     | | | |___| |_|   __|___ ___|  _  |___ ___| |_ ___
#     | | | | -_| . |__   | -_|  _|   __|  _| . | . | -_|
#     |_____|___|___|_____|___|___|__|  |_| |___|___|___|
#          Web Security Assessment Tool
#
# [~] Version      : 0.0.12
# [~] Created By   : Spyboy
#  ╰➤ Twitter      : https://spyboy.in/twitter
#  ╰➤ Discord      : https://spyboy.in/Discord
#  ╰➤ Website      : https://spyboy.in/
#  ╰➤ Blog         : https://spyboy.blog/
#  ╰➤ Github       : https://github.com/spyboy-productions/WebSecProbe
#
#
# +-------------------------------------------------------------------+---------------+------------------+
# | URL                                                               |   Status Code |   Content Length |
# +===================================================================+===============+==================+
# ...
